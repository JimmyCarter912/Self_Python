# %% [markdown]
# #First Program For Python (Self Learning)

# %%
name = "Jimmy Carter"
print (name)
# Out:
# Jimmy Carter

# %%
a = 1
b = 2
c = 3
d = 4
e = 5
print (b)
print (a+b)
print (b*e)
print (d/b)
# Out:
# 2
# 3
# 10
# 2.0

# %%
name = "Jimmy"
print (name*10)
# Out:
# JimmyJimmyJimmyJimmyJimmyJimmyJimmyJimmyJimmyJimmy

# %% [markdown]
# String Shenanigans

# %%
'hello jimmy'[1:10]
# Out:
# 'ello jimm'

# %%
path = "c:\documents\navin"
print (path)
# Out:
# c:\documents
# avin

# %% [markdown]
# #to solve this

# %%
path = r"c:\documents\navin"
print (path)
# Out:
# c:\documents\navin

# %% [markdown]
# #im a be honest this is a pice of shit

# %% [markdown]
# #im so done
